# %%
print("hello world")

# %%
# %sql
select 'hello world from sql!'

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
# this is a markdown note with **bold** and *italicised* in it
#
# ordered list
# 1. first
# 2. second
# 3. third
#
# unordered list
# * coffee
# * tea
# * milk
#
# images:
# ![databricks de associate badge](https://www.)
#
# and of course, tables:
#
# | user_id | user_name |
# |---------|-----------|
# |    1    |  Adam     |
# |    2    |  Sarah    |
#
# Links (or embedded HTML): <a href="https://docs.databricks.com/notebooks/notebooks-manage.html" target="_blank"> Managing Notebook documentation</a>

# %%
# %run ./Includes/setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()
dbutils.fs.ls("dbfs:/")

# %%
files = dbutils.fs.ls('/databricks-datasets/')
display(files)
